# %% [markdown]
# # PYTHON DATATYPES

# %%
string_eg = 'Bala'   # String datatype

# %%
type(string_eg)
# Out:
# str

# %% [markdown]
# BASIC TYPES

# %%
a = 3       # Integer
b = 3.5     # Float
c = True    # Boolean
d = 'raja'  # String

# %% [markdown]
# COLLECTION TYPES

# %%
list_eg = [1,'bala',1.2,True]  # List with different datatypes
print(list_eg)
# Out:
# [1, 'bala', 1.2, True]

# %%
list_eg[0]=2   # Replace the 1st element with the value 2.

# %%
print(list_eg)    # Printing the final list
# Out:
# [2, 'bala', 1.2, True]

# %%
tuple_eg = (1,'bala',1.2,True)  # Creating a tuple with diff datatypes
print(tuple_eg)
# Out:
# (1, 'bala', 1.2, True)

# %%
tuple_eg[0]= 2    # Trying to replace the value, but tuple is immutable. Gives error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-228/403047095.py in <cell line: 0>()
# ----> 1 tuple_eg[0]= 2    # Trying to replace the value, but tuple is immutable. Gives error
#
# TypeError: 'tuple' object does not support item assignment

# %%
set_eg = {True, 5, 2.1, 10, 'bala'}   # Creating a set with diff datatypes
print(set_eg)
# Out:
# {True, 2.1, 'bala', 5, 10}

# %%
set_eg1 = {1, 2, 3, 4, 4, 2, 3}      # It is Unordered and unique values
print(set_eg1)
# Out:
# {1, 2, 3, 4}

# %%
set_2 = {True, 1, 5, 6, 'bala',5}    # No duplicates
print(set_2)
# Out:
# {True, 'bala', 5, 6}

# %%
True==1      # Checking the condition
# Out:
# True

# %%
# Creating a dcitionary with key values paires

dict_eg = {
    'name': 'bala',
    'age': 25
}

# %%
dict_eg
# Out:
# {'name': 'bala', 'age': 25}

# %%
dict_eg['age']    # Accessing the value with key
# Out:
# 25

# %%
# List (ordered, mutable)

colors = ["red", "blue", "green"]

# Tuple (ordered, immutable)

coordinates = (10, 20)

# Set (unordered, unique)

unique_ids = {101, 102, 103}

# Dictionary (key-value pairs)

student = {"name": "Alice", "age": 21}

# %% [markdown]
# OPERATORS

# %% [markdown]
# - ARITHMATIC OPERATORS

# %%
x = 10

y = 5

# %%
x+y  # Addition
# Out:
# 15

# %%
x-y   # Subtraction
# Out:
# 5

# %%
x*y  # Multiplication
# Out:
# 50

# %%
x/y  # Division
# Out:
# 2.0

# %%
x**y  # Power
# Out:
# 100000

# %%
x%y   # Modulus
# Out:
# 0

# %% [markdown]
# - COMPARISION OPERATORS

# %% [markdown]
# Comparing the values using operators

# %%
x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x
# Out:
# 10

# %%
x>=y
# Out:
# True

# %% [markdown]
# - LOGICAL OPERATORS

# %% [markdown]
# Checking two or more conditions with and, or, not logical operators

# %%
x >= 5
# Out:
# True

# %%
y>=11
# Out:
# False

# %%
(x >= 5) and (y>=11)
# Out:
# False

# %%
(x >= 5) or (y>=11)
# Out:
# True

# %%
not((x >= 5) or (y>=11))
# Out:
# False

# %% [markdown]
# - ASSIGNEMENT OPERATORS

# %% [markdown]
# Assigning the value to the variable

# %%
a=1

# %%
a
# Out:
# 1

# %%
a += 1

# %%
a
# Out:
# 2

# %%
# a+=1---> a = a+1

# %% [markdown]
# - MEMBERSHIP AND IDENTITY OPERATORS

# %%
color = ['red','blue','green','orange']
color
# Out:
# ['red', 'blue', 'green', 'orange']

# %%
'red' in color    # Checking the value inside the list using "in" operators
# Out:
# True

# %%
'yellow' in color
# Out:
# False

# %%
c = 10

# %%
c is 10    # checking with 'is' operators
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipython-input-228/691488799.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   c is 10    # checking with 'is' operators
# False

# %% [markdown]
# ### TYPE CHECKING

# %% [markdown]
# Checking the datatype of a variable

# %%
type(x)
# Out:
# int

# %%
type(color)
# Out:
# list
