# %% [markdown]
# # SAMPLE HELLO WORLD! PROGRAM

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Printing a simple python program

# %% [markdown]
# # RUNNING A CODE IN COLAB

# %%
a = 10
b = 20

a+b
# Out:
# 30

# %% [markdown]
# Running a code and do some mathematical operations

# %% [markdown]
# # IMPORTING POPULAR PYTHON PACKAGES

# %%
import math       # for mathematical functions

import os         # for file management

import random     # for random numbers

import requests   # for API calls

import pandas as pd  # for data analysis

# %% [markdown]
# Importing basic python packages inside colab.
